# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import numpy as np 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Load the dataset

# %%
DF = pd.read_csv("Hotel Reservations Dataset.csv")

# %% [markdown]
# #### Explore data

# %%
DF.head(15)
# Out:
#     no_of_adults  no_of_children type_of_meal_plan  \
# 0              2               0       Meal Plan 1
# 1              2               0      Not Selected
# 2              1               0       Meal Plan 1
# 3              2               0       Meal Plan 1
# 4              2               0      Not Selected
# 5              2               0       Meal Plan 2
# 6              2               0       Meal Plan 1
# 7              2               0       Meal Plan 1
# 8              3               0       Meal Plan 1
# 9              2               0       Meal Plan 1
# 10             1               0      Not Selected
# 11             1               0       Meal Plan 1
# 12             2               0      Not Selected
# 13             2               0      Not Selected
# 14             2               0      Not Selected
#
#     required_car_parking_space room_type_reserved  lead_time  arrival_year  \
# ...

# %% [markdown]
# ##### Check Shape of the data

# %%
DF.shape
# Out:
# (25299, 12)

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25299 entries, 0 to 25298
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   no_of_adults                25299 non-null  int64
#  1   no_of_children              25299 non-null  int64
#  2   type_of_meal_plan           25299 non-null  object
#  3   required_car_parking_space  25299 non-null  int64
#  4   room_type_reserved          25299 non-null  object
#  5   lead_time                   25299 non-null  int64
#  6   arrival_year                25299 non-null  int64
#  7   arrival_month               25299 non-null  int64
#  8   arrival_date                25299 non-null  int64
#  9   market_segment_type         25299 non-null  object
#  10  avg_price_per_room          25124 non-null  float64
#  11  booking_status              25299 non-null  int64
# dtypes: float64(1), int64(8), object(3)
# memory usage: 2.3+ MB

# %% [markdown]
# #### Explore the Structure

# %%
DF.describe()
# Out:
#        no_of_adults  no_of_children  required_car_parking_space     lead_time  \
# count   25299.00000    25299.000000                25299.000000  25299.000000
# mean        1.89715        0.144393                    0.042848     67.009012
# std         0.52664        0.467098                    0.203102     68.777542
# min         0.00000        0.000000                    0.000000      0.000000
# 25%         2.00000        0.000000                    0.000000     12.000000
# 50%         2.00000        0.000000                    0.000000     45.000000
# 75%         2.00000        0.000000                    0.000000    101.000000
# max         4.00000       10.000000                    2.000000    443.000000
#
#        arrival_year  arrival_month  arrival_date  avg_price_per_room  \
# count  25299.000000   25299.000000  25299.000000        25124.000000
# mean    2017.854026       7.330132     15.765880          106.140796
# ...

# %%
DF.describe(include = 'object')
# Out:
#        type_of_meal_plan room_type_reserved market_segment_type
# count              25299              25299               25299
# unique                 4                  7                   5
# top          Meal Plan 1        Room_Type 1              Online
# freq               19793              18031               19694

# %%
DF.dtypes
# Out:
# no_of_adults                    int64
# no_of_children                  int64
# type_of_meal_plan              object
# required_car_parking_space      int64
# room_type_reserved             object
# lead_time                       int64
# arrival_year                    int64
# arrival_month                   int64
# arrival_date                    int64
# market_segment_type            object
# avg_price_per_room            float64
# booking_status                  int64
# dtype: object

# %% [markdown]
# #### Check Duplicates

# %%
DF.duplicated().sum()
# Out:
# 112

# %%
DF[DF.duplicated()]
# Out:
#        no_of_adults  no_of_children type_of_meal_plan  \
# 25187             2               0       Meal Plan 1
# 25188             3               0       Meal Plan 1
# 25189             2               0       Meal Plan 1
# 25190             1               0      Not Selected
# 25191             1               0       Meal Plan 1
# ...             ...             ...               ...
# 25294             2               1       Meal Plan 1
# 25295             1               0       Meal Plan 1
# 25296             1               0       Meal Plan 1
# 25297             1               0       Meal Plan 1
# 25298             2               0       Meal Plan 1
#
#        required_car_parking_space room_type_reserved  lead_time  arrival_year  \
# 25187                           0        Room_Type 4         83          2018
# 25188                           0        Room_Type 1        121          2018
# 25189                           0        Room_Type 4         44          2018
# ...

# %% [markdown]
# #### Deal with duplicates

# %%
DF1 = DF.drop_duplicates()
DF1
# Out:
#        no_of_adults  no_of_children type_of_meal_plan  \
# 0                 2               0       Meal Plan 1
# 1                 2               0      Not Selected
# 2                 1               0       Meal Plan 1
# 3                 2               0       Meal Plan 1
# 4                 2               0      Not Selected
# ...             ...             ...               ...
# 25182             2               2       Meal Plan 1
# 25183             3               0       Meal Plan 1
# 25184             2               0       Meal Plan 1
# 25185             2               0       Meal Plan 1
# 25186             2               0      Not Selected
#
#        required_car_parking_space room_type_reserved  lead_time  arrival_year  \
# 0                               0        Room_Type 1        224          2017
# 1                               0        Room_Type 1          5          2018
# 2                               0        Room_Type 1          1          2018
# ...

# %% [markdown]
# #### Check Missing Values
#
# - Use graphical and no graphical approach ( hint: pandas function and missingno library)

# %%
DF.isnull().sum()
# Out:
# no_of_adults                    0
# no_of_children                  0
# type_of_meal_plan               0
# required_car_parking_space      0
# room_type_reserved              0
# lead_time                       0
# arrival_year                    0
# arrival_month                   0
# arrival_date                    0
# market_segment_type             0
# avg_price_per_room            175
# booking_status                  0
# dtype: int64

# %%
# !pip install missingno

# %%
import missingno as mgo

# %%
mgo.bar(DF1) #This shows that avg_price_per_person have some missing values
# Out:
# <Axes: >

# %%
mgo.matrix(DF1)
# Out:
# <Axes: >

# %%
missing_values_count = DF1.isnull().sum()
missing_values_count
# Out:
# no_of_adults                    0
# no_of_children                  0
# type_of_meal_plan               0
# required_car_parking_space      0
# room_type_reserved              0
# lead_time                       0
# arrival_year                    0
# arrival_month                   0
# arrival_date                    0
# market_segment_type             0
# avg_price_per_room            172
# booking_status                  0
# dtype: int64

# %%
missing_values_count.loc[missing_values_count > 0].plot(kind='bar', figsize=(12,8))
plt.xticks(rotation=45)
plt.show()

# %%
sns.heatmap(DF1.isnull().transpose())
# Out:
# <Axes: >

# %%
DF1.isnull().sum()
# Out:
# no_of_adults                    0
# no_of_children                  0
# type_of_meal_plan               0
# required_car_parking_space      0
# room_type_reserved              0
# lead_time                       0
# arrival_year                    0
# arrival_month                   0
# arrival_date                    0
# market_segment_type             0
# avg_price_per_room            172
# booking_status                  0
# dtype: int64

# %% [markdown]
# #### Deal with Missing values

# %%
DF1[DF1['avg_price_per_room'].isnull()]
# Out:
#      no_of_adults  no_of_children type_of_meal_plan  \
# 34              2               0       Meal Plan 1
# 35              0               2       Meal Plan 1
# 36              2               0      Not Selected
# 37              2               0       Meal Plan 1
# 38              2               0      Not Selected
# ..            ...             ...               ...
# 954             2               0       Meal Plan 1
# 955             2               0      Not Selected
# 956             3               1       Meal Plan 1
# 957             3               0       Meal Plan 1
# 958             2               0      Not Selected
#
#      required_car_parking_space room_type_reserved  lead_time  arrival_year  \
# 34                            0        Room_Type 1        107          2018
# 35                            0        Room_Type 2         56          2018
# 36                            0        Room_Type 1          2          2018
# ...

# %%
#Check the percentage of missing values

DF1.isnull().mean()*100
# Out:
# no_of_adults                  0.000000
# no_of_children                0.000000
# type_of_meal_plan             0.000000
# required_car_parking_space    0.000000
# room_type_reserved            0.000000
# lead_time                     0.000000
# arrival_year                  0.000000
# arrival_month                 0.000000
# arrival_date                  0.000000
# market_segment_type           0.000000
# avg_price_per_room            0.682892
# booking_status                0.000000
# dtype: float64

# %%
#Null or missing values is a small percentage of total rows and won't much effect the data, we can drop them

DF1.dropna(subset = "avg_price_per_room", inplace = True)
# Out:
# C:\Users\Atif Ali Hafeez\AppData\Local\Temp\ipykernel_9288\1614674935.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF1.dropna(subset = "avg_price_per_room", inplace = True)

# %%
DF1.isnull().sum()
# Out:
# no_of_adults                  0
# no_of_children                0
# type_of_meal_plan             0
# required_car_parking_space    0
# room_type_reserved            0
# lead_time                     0
# arrival_year                  0
# arrival_month                 0
# arrival_date                  0
# market_segment_type           0
# avg_price_per_room            0
# booking_status                0
# dtype: int64

# %% [markdown]
# #### Encoding
#
# **Identify columns and then find a suitable technique for it**

# %%
DF1.select_dtypes(include = 'object').columns.tolist()
# Out:
# ['type_of_meal_plan', 'room_type_reserved', 'market_segment_type']

# %%
categ_column = DF1.select_dtypes(include = 'object').columns
categ_column
# Out:
# Index(['type_of_meal_plan', 'room_type_reserved', 'market_segment_type'], dtype='object')

# %%
DF1['type_of_meal_plan'].unique()
# Out:
# array(['Meal Plan 1', 'Not Selected', 'Meal Plan 2', 'Meal Plan 3'],
#       dtype=object)

# %%
for i in categ_column:

  a = DF1[i].unique()
  print('The categories are:', a)
  print('\n\n')
  b = DF1[i].value_counts()
  print(b)
  print("\n\n")
# Out:
# The categories are: ['Meal Plan 1' 'Not Selected' 'Meal Plan 2' 'Meal Plan 3']
#
#
#
# type_of_meal_plan
# Meal Plan 1     19593
# Not Selected     4325
# Meal Plan 2      1091
# Meal Plan 3         6
# Name: count, dtype: int64
#
#
#
# The categories are: ['Room_Type 1' 'Room_Type 4' 'Room_Type 2' 'Room_Type 3' 'Room_Type 6'
#  'Room_Type 7' 'Room_Type 5']
#
#
#
# room_type_reserved
# Room_Type 1    17815
# Room_Type 4     5288
# Room_Type 6      929
# Room_Type 2      589
# Room_Type 5      232
# Room_Type 7      154
# Room_Type 3        8
# Name: count, dtype: int64
#
#
#
# The categories are: ['Offline' 'Online' 'Corporate' 'Aviation' 'Complementary']
#
#
#
# market_segment_type
# Online           19476
# Offline           3889
# Corporate         1236
# Complementary      325
# Aviation            89
# Name: count, dtype: int64

# %%
DF1 = pd.get_dummies(DF1 , columns = ['type_of_meal_plan'] , dtype = int)
DF1.head(15)
# Out:
#     no_of_adults  no_of_children  required_car_parking_space  \
# 0              2               0                           0
# 1              2               0                           0
# 2              1               0                           0
# 3              2               0                           0
# 4              2               0                           0
# 5              2               0                           0
# 6              2               0                           0
# 7              2               0                           0
# 8              3               0                           0
# 9              2               0                           0
# 10             1               0                           0
# 11             1               0                           0
# 12             2               0                           0
# 13             2               0                           1
# ...

# %%
# !pip install category_encoders
import category_encoders as ce
# Out:
# ...
#    ---------------------------------------- 0.0/81.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/81.9 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/81.9 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/81.9 kB ? eta -:--:--
#    --------------- ------------------------ 30.7/81.9 kB 187.9 kB/s eta 0:00:01
#    ------------------------------ --------- 61.4/81.9 kB 273.8 kB/s eta 0:00:01
#    ---------------------------------------- 81.9/81.9 kB 327.0 kB/s eta 0:00:00
# ...

# %%
encoder = ce.BinaryEncoder(cols = ['room_type_reserved'])
DF1 = encoder.fit_transform(DF1)
DF1.head(15)
# Out:
#     no_of_adults  no_of_children  required_car_parking_space  \
# 0              2               0                           0
# 1              2               0                           0
# 2              1               0                           0
# 3              2               0                           0
# 4              2               0                           0
# 5              2               0                           0
# 6              2               0                           0
# 7              2               0                           0
# 8              3               0                           0
# 9              2               0                           0
# 10             1               0                           0
# 11             1               0                           0
# 12             2               0                           0
# 13             2               0                           1
# ...

# %%
DF1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25015 entries, 0 to 25186
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   no_of_adults                    25015 non-null  int64
#  1   no_of_children                  25015 non-null  int64
#  2   required_car_parking_space      25015 non-null  int64
#  3   room_type_reserved_0            25015 non-null  int64
#  4   room_type_reserved_1            25015 non-null  int64
#  5   room_type_reserved_2            25015 non-null  int64
#  6   lead_time                       25015 non-null  int64
#  7   arrival_year                    25015 non-null  int64
#  8   arrival_month                   25015 non-null  int64
#  9   arrival_date                    25015 non-null  int64
#  10  market_segment_type             25015 non-null  object
#  11  avg_price_per_room              25015 non-null  float64
# ...
